# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://docs.deepnote.com/environment/custom-initialization).

# %%
# %%bash
# # If you imported a project with a 'requirements.txt' file, we'll install it here apart from blacklisted packages that interfere with Deepnote (see above).
# if test -f requirements.txt
#   then
#     sed -i '/jedi/d;/jupyter/d;' ./requirements.txt
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install. This is the case with most projects."
# fi
# Out:
# There's no requirements.txt, so nothing to install. This is the case with most projects.

# %%
# %%bash
# # If you have previously installed any packages into this project, we re-install them here to restore your environment.
# if test -f .deepnote/requirements.txt
#   then
#     sed -i '/jupyter/d' .deepnote/requirements.txt
#     pip install -r .deepnote/requirements.txt
#   else echo "Seems like there is nothing to restore. Most likely, you haven't installed any extra packages so far."
# fi
# Out:
# Collecting appdirs==1.4.4
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: attrs==19.3.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 2)) (19.3.0)
# Requirement already satisfied: backcall==0.2.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 3)) (0.2.0)
# Requirement already satisfied: bleach==3.1.5 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 4)) (3.1.5)
# Requirement already satisfied: certifi==2020.6.20 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 5)) (2020.6.20)
# Requirement already satisfied: chardet==3.0.4 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 6)) (3.0.4)
# Requirement already satisfied: cycler==0.10.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 7)) (0.10.0)
# Requirement already satisfied: decorator==4.4.2 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 8)) (4.4.2)
# Requirement already satisfied: defusedxml==0.6.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 9)) (0.6.0)
# Collecting distlib==0.3.1
#   Downloading distlib-0.3.1-py2.py3-none-any.whl (335 kB)
# Collecting docopt==0.6.2
#   Downloading docopt-0.6.2.tar.gz (25 kB)
# Requirement already satisfied: entrypoints==0.3 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 12)) (0.3)
# Collecting filelock==3.0.12
#   Downloading filelock-3.0.12-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: idna==2.10 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 14)) (2.10)
# Requirement already satisfied: importlib-metadata==1.7.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 15)) (1.7.0)
# Requirement already satisfied: ipykernel==5.3.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 16)) (5.3.1)
# Requirement already satisfied: ipython==7.16.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 17)) (7.16.1)
# Requirement already satisfied: ipython-genutils==0.2.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 18)) (0.2.0)
# Requirement already satisfied: ipywidgets==7.5.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 19)) (7.5.1)
# Requirement already satisfied: jedi==0.17.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 20)) (0.17.1)
# Requirement already satisfied: Jinja2==2.11.2 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 21)) (2.11.2)
# Requirement already satisfied: joblib==0.16.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 22)) (0.16.0)
# Requirement already satisfied: jsonschema==3.2.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 23)) (3.2.0)
# Requirement already satisfied: kiwisolver==1.2.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 24)) (1.2.0)
# Requirement already satisfied: MarkupSafe==1.1.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 25)) (1.1.1)
# Requirement already satisfied: matplotlib==3.2.2 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 26)) (3.2.2)
# Requirement already satisfied: mistune==0.8.4 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 27)) (0.8.4)
# Requirement already satisfied: nbconvert==5.6.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 28)) (5.6.1)
# Requirement already satisfied: nbformat==5.0.7 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 29)) (5.0.7)
# Requirement already satisfied: numpy==1.19.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 30)) (1.19.0)
# Requirement already satisfied: packaging==20.4 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 31)) (20.4)
# Requirement already satisfied: pandas==1.0.5 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 32)) (1.0.5)
# Requirement already satisfied: pandocfilters==1.4.2 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 33)) (1.4.2)
# Requirement already satisfied: parso==0.7.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 34)) (0.7.0)
# Requirement already satisfied: pexpect==4.8.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 35)) (4.8.0)
# Requirement already satisfied: pickleshare==0.7.5 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 36)) (0.7.5)
# Collecting pipenv==2020.6.2
#   Downloading pipenv-2020.6.2-py2.py3-none-any.whl (3.9 MB)
# Requirement already satisfied: pluggy==1.0.0.dev0 in /opt/venv/lib/python3.7/site-packages/pluggy-1.0.0.dev0-py3.7.egg (from -r .deepnote/requirements.txt (line 38)) (1.0.0.dev0)
# Requirement already satisfied: prometheus-client==0.8.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 39)) (0.8.0)
# Requirement already satisfied: prompt-toolkit==3.0.5 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 40)) (3.0.5)
# Requirement already satisfied: ptyprocess==0.6.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 41)) (0.6.0)
# Requirement already satisfied: Pygments==2.6.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 42)) (2.6.1)
# Requirement already satisfied: pyparsing==2.4.7 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 43)) (2.4.7)
# Requirement already satisfied: pyrsistent==0.16.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 44)) (0.16.0)
# Requirement already satisfied: python-dateutil==2.8.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 45)) (2.8.1)
# Requirement already satisfied: python-jsonrpc-server==0.3.4 in /opt/venv/lib/python3.7/site-packages/python_jsonrpc_server-0.3.4-py3.7.egg (from -r .deepnote/requirements.txt (line 46)) (0.3.4)
# Requirement already satisfied: python-language-server===deepnote-0.02 in /opt/venv/lib/python3.7/site-packages/python_language_server-deepnote_0.02-py3.7.egg (from -r .deepnote/requirements.txt (line 47)) (deepnote-0.02)
# Requirement already satisfied: pytz==2020.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 48)) (2020.1)
# Requirement already satisfied: pyzmq==19.0.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 49)) (19.0.1)
# Requirement already satisfied: requests==2.24.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 50)) (2.24.0)
# Requirement already satisfied: scikit-learn==0.23.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 51)) (0.23.1)
# Requirement already satisfied: scipy==1.5.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 52)) (1.5.1)
# Requirement already satisfied: Send2Trash==1.5.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 53)) (1.5.0)
# Requirement already satisfied: six==1.15.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 54)) (1.15.0)
# Requirement already satisfied: terminado==0.8.3 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 55)) (0.8.3)
# Requirement already satisfied: testpath==0.4.4 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 56)) (0.4.4)
# Collecting thingspeak==1.0.0
#   Downloading thingspeak-1.0.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: threadpoolctl==2.1.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 58)) (2.1.0)
# Requirement already satisfied: tornado==6.0.4 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 59)) (6.0.4)
# Requirement already satisfied: traitlets==4.3.3 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 60)) (4.3.3)
# Requirement already satisfied: ujson==1.35 in /opt/venv/lib/python3.7/site-packages/ujson-1.35-py3.7-linux-x86_64.egg (from -r .deepnote/requirements.txt (line 61)) (1.35)
# Collecting urllib3==1.25.10
#   Downloading urllib3-1.25.10-py2.py3-none-any.whl (127 kB)
# Collecting virtualenv==20.0.30
#   Downloading virtualenv-20.0.30-py2.py3-none-any.whl (7.1 MB)
# Collecting virtualenv-clone==0.5.4
#   Downloading virtualenv_clone-0.5.4-py2.py3-none-any.whl (6.6 kB)
# Requirement already satisfied: wcwidth==0.2.5 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 65)) (0.2.5)
# Requirement already satisfied: webencodings==0.5.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 66)) (0.5.1)
# Requirement already satisfied: widgetsnbextension==3.5.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 67)) (3.5.1)
# Requirement already satisfied: zipp==3.1.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 68)) (3.1.0)
# Requirement already satisfied: jupyter-client in /opt/venv/lib/python3.7/site-packages (from ipykernel==5.3.1->-r .deepnote/requirements.txt (line 16)) (6.1.5)
# Requirement already satisfied: setuptools>=18.5 in /opt/venv/lib/python3.7/site-packages (from ipython==7.16.1->-r .deepnote/requirements.txt (line 17)) (47.3.1)
# Requirement already satisfied: jupyter-core in /opt/venv/lib/python3.7/site-packages (from nbconvert==5.6.1->-r .deepnote/requirements.txt (line 28)) (4.6.3)
# Requirement already satisfied: pip>=18.0 in /opt/venv/lib/python3.7/site-packages (from pipenv==2020.6.2->-r .deepnote/requirements.txt (line 37)) (20.1.1)
# Requirement already satisfied: notebook>=4.4.1 in /opt/venv/lib/python3.7/site-packages (from widgetsnbextension==3.5.1->-r .deepnote/requirements.txt (line 67)) (7.0.0.dev0)
# Building wheels for collected packages: docopt
#   Building wheel for docopt (setup.py): started
#   Building wheel for docopt (setup.py): finished with status 'done'
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13704 sha256=4db91428a4eaba3addc6b9cc9477840bba64cdcf12d0a26d52d853c035ae7e6f
#   Stored in directory: /home/jovyan/.cache/pip/wheels/72/b0/3f/1d95f96ff986c7dfffe46ce2be4062f38ebd04b506c77c81b9
# Successfully built docopt
# Installing collected packages: appdirs, distlib, docopt, filelock, virtualenv-clone, virtualenv, pipenv, thingspeak, urllib3
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.25.9
#     Uninstalling urllib3-1.25.9:
#       Successfully uninstalled urllib3-1.25.9
# Successfully installed appdirs-1.4.4 distlib-0.3.1 docopt-0.6.2 filelock-3.0.12 pipenv-2020.6.2 thingspeak-1.0.0 urllib3-1.25.10 virtualenv-20.0.30 virtualenv-clone-0.5.4
# WARNING: You are using pip version 20.1.1; however, version 20.2.2 is available.
# You should consider upgrading via the '/opt/venv/bin/python -m pip install --upgrade pip' command.
