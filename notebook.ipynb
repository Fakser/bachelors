# %%
# !pip install openpyxl
import thingspeak
import json
import os
import time

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: openpyxl in /opt/venv/lib/python3.7/site-packages (3.0.4)
# Requirement already satisfied: jdcal in /opt/venv/lib/python3.7/site-packages (from openpyxl) (1.4.1)
# Requirement already satisfied: et-xmlfile in /opt/venv/lib/python3.7/site-packages (from openpyxl) (1.0.1)
# WARNING: You are using pip version 20.1.1; however, version 20.2.2 is available.
# You should consider upgrading via the '/opt/venv/bin/python -m pip install --upgrade pip' command.

# %%
start = time.time()
raw_data_from_room = thingspeak.Channel(1044783).get()
raw_data_from_garage = thingspeak.Channel(775156).get()

# %%
dict_data_from_room = json.loads(raw_data_from_room)
dict_data_from_garage = json.loads(raw_data_from_garage)

# %%
dict_data_from_room['feeds']
# Out:
# [{'created_at': '2020-08-13T12:30:50Z',
#   'entry_id': 62109,
#   'field1': None,
#   'field2': None,
#   'field3': '0.00'},
#  {'created_at': '2020-08-13T12:31:06Z',
#   'entry_id': 62110,
#   'field1': '2099.00',
#   'field2': None,
#   'field3': None},
#  {'created_at': '2020-08-13T12:31:22Z',
#   'entry_id': 62111,
#   'field1': None,
#   'field2': '67.00',
#   'field3': None},
#  {'created_at': '2020-08-13T12:31:39Z',
#   'entry_id': 62112,
#   'field1': None,
#   'field2': None,
#   'field3': '0.00'},
#  {'created_at': '2020-08-13T12:31:55Z',
#   'entry_id': 62113,
#   'field1': '2082.00',
#   'field2': None,
#   'field3': None},
#  {'created_at': '2020-08-13T12:32:12Z',
#   'entry_id': 62114,
#   'field1': None,
#   'field2': '67.00',
#   'field3': None},
#  {'created_at': '2020-08-13T12:32:28Z',
#   'entry_id': 62115,
#   'field1': None,
#   'field2': None,
#   'field3': '0.00'},
#  {'created_at': '2020-08-13T12:32:44Z',
#   'entry_id': 62116,
#   'field1': '2083.00',
#   'field2': None,
#   'field3': None},
#  {'created_at': '2020-08-13T12:33:01Z',
#   'entry_id': 62117,
#   'field1': None,
#   'field2': '64.00',
#   'field3': None},
#  {'created_at': '2020-08-13T12:33:17Z',
#   'entry_id': 62118,
#   'field1': None,
#   'field2': None,
#   'field3': '0.00'},
#  {'created_at': '2020-08-13T12:33:33Z',
#   'entry_id': 62119,
#   'field1': '2027.00',
#   'field2': None,
#   'field3': None},
#  {'created_at': '2020-08-13T12:33:50Z',
#   'entry_id': 62120,
#   'field1': None,
#   'field2': '66.00',
#   'field3': None},
#  {'created_at': '2020-08-13T12:34:06Z',
#   'entry_id': 62121,
#   'field1': None,
#   'field2': None,
#   'field3': '0.00'},
#  {'created_at': '2020-08-13T12:34:23Z',
#   'entry_id': 62122,
#   'field1': '2009.00',
#   'field2': None,
#   'field3': None},
#  {'created_at': '2020-08-13T12:34:39Z',
#   'entry_id': 62123,
#   'field1': None,
#   'field2': '65.00',
#   'field3': None},
#  {'created_at': '2020-08-13T12:34:55Z',
#   'entry_id': 62124,
#   'field1': None,
#   'field2': None,
#   'field3': '0.00'},
#  {'created_at': '2020-08-13T12:35:12Z',
#   'entry_id': 62125,
#   'field1': '2000.00',
#   'field2': None,
#   'field3': None},
#  {'created_at': '2020-08-13T12:35:28Z',
#   'entry_id': 62126,
#   'field1': None,
#   'field2': '67.00',
#   'field3': None},
#  {'created_at': '2020-08-13T12:35:45Z',
#   'entry_id': 62127,
#   'field1': None,
#   'field2': None,
#   'field3': '0.00'},
#  {'created_at': '2020-08-13T12:36:01Z',
#   'entry_id': 62128,
#   'field1': '1938.00',
#   'field2': None,
#   'field3': None},
#  {'created_at': '2020-08-13T12:36:18Z',
#   'entry_id': 62129,
#   'field1': None,
#   'field2': '65.00',
#   'field3': None},
#  {'created_at': '2020-08-13T12:36:34Z',
#   'entry_id': 62130,
#   'field1': None,
#   'field2': None,
#   'field3': '0.00'},
#  {'created_at': '2020-08-13T12:36:51Z',
#   'entry_id': 62131,
#   'field1': '1874.00',
#   'field2': None,
#   'field3': None},
#  {'created_at': '2020-08-13T12:37:07Z',
#   'entry_id': 62132,
#   'field1': None,
#   'field2': '65.00',
#   'field3': None},
#  {'created_at': '2020-08-13T12:37:23Z',
#   'entry_id': 62133,
#   'field1': None,
#   'field2': None,
#   'field3': '0.00'},
#  {'created_at': '2020-08-13T12:37:40Z',
#   'entry_id': 62134,
#   'field1': '1781.00',
#   'field2': None,
#   'field3': None},
#  {'created_at': '2020-08-13T12:37:56Z',
#   'entry_id': 62135,
#   'field1': None,
#   'field2': '66.00',
#   'field3': None},
#  {'created_at': '2020-08-13T12:38:13Z',
#   'entry_id': 62136,
#   'field1': None,
#   'field2': None,
#   'field3': '0.00'},
#  {'created_at': '2020-08-13T12:38:29Z',
#   'entry_id': 62137,
#   'field1': '1717.00',
#   'field2': None,
#   'field3': None},
#  {'created_at': '2020-08-13T12:38:46Z',
#   'entry_id': 62138,
#   'field1': None,
#   'field2': '66.00',
#   'field3': None},
#  {'created_at': '2020-08-13T12:39:02Z',
#   'entry_id': 62139,
#   'field1': None,
#   'field2': None,
#   'field3': '0.00'},
#  {'created_at': '2020-08-13T12:39:18Z',
#   'entry_id': 62140,
#   'field1': '1734.00',
#   'field2': None,
#   'field3': None},
#  {'created_at': '2020-08-13T12:39:35Z',
#   'entry_id': 62141,
#   'field1': None,
#   'field2': '67.00',
#   'field3': None},
#  {'created_at': '2020-08-13T12:39:51Z',
#   'entry_id': 62142,
#   'field1': None,
#   'field2': None,
#   'field3': '0.00'},
#  {'created_at': '2020-08-13T12:40:08Z',
#   'entry_id': 62143,
#   'field1': '1774.00',
#   'field2': None,
#   'field3': None},
#  {'created_at': '2020-08-13T12:40:24Z',
#   'entry_id': 62144,
#   'field1': None,
#   'field2': '66.00',
#   'field3': None},
#  {'created_at': '2020-08-13T12:40:41Z',
#   'entry_id': 62145,
#   'field1': None,
#   'field2': None,
#   'field3': '0.00'},
#  {'created_at': '2020-08-13T12:40:57Z',
#   'entry_id': 62146,
#   'field1': '1840.00',
#   'field2': None,
#   'field3': None},
#  {'created_at': '2020-08-13T12:41:14Z',
#   'entry_id': 62147,
#   'field1': None,
#   'field2': '65.00',
#   'field3': None},
#  {'created_at': '2020-08-13T12:41:30Z',
#   'entry_id': 62148,
#   'field1': None,
#   'field2': None,
#   'field3': '0.00'},
#  {'created_at': '2020-08-13T12:41:47Z',
#   'entry_id': 62149,
#   'field1': '1785.00',
#   'field2': None,
#   'field3': None},
#  {'created_at': '2020-08-13T12:42:03Z',
#   'entry_id': 62150,
#   'field1': None,
#   'field2': '67.00',
#   'field3': None},
#  {'created_at': '2020-08-13T12:42:19Z',
#   'entry_id': 62151,
#   'field1': None,
#   'field2': None,
#   'field3': '0.00'},
#  {'created_at': '2020-08-13T12:42:36Z',
#   'entry_id': 62152,
#   'field1': '1786.00',
#   'field2': None,
#   'field3': None},
#  {'created_at': '2020-08-13T12:42:52Z',
#   'entry_id': 62153,
#   'field1': None,
#   'field2': '66.00',
#   'field3': None},
#  {'created_at': '2020-08-13T12:43:09Z',
#   'entry_id': 62154,
#   'field1': None,
#   'field2': None,
#   'field3': '0.00'},
#  {'created_at': '2020-08-13T12:43:25Z',
#   'entry_id': 62155,
#   'field1': '1836.00',
#   'field2': None,
#   'field3': None},
#  {'created_at': '2020-08-13T12:43:42Z',
#   'entry_id': 62156,
#   'field1': None,
#   'field2': '67.00',
#   'field3': None},
#  {'created_at': '2020-08-13T12:43:58Z',
#   'entry_id': 62157,
#   'field1': None,
#   'field2': None,
#   'field3': '0.00'},
#  {'created_at': '2020-08-13T12:44:14Z',
#   'entry_id': 62158,
#   'field1': '1889.00',
#   'field2': None,
#   'field3': None},
#  {'created_at': '2020-08-13T12:44:31Z',
#   'entry_id': 62159,
#   'field1': None,
#   'field2': '66.00',
#   'field3': None},
#  {'created_at': '2020-08-13T12:44:47Z',
#   'entry_id': 62160,
#   'field1': None,
#   'field2': None,
#   'field3': '0.00'},
#  {'created_at': '2020-08-13T12:45:04Z',
#   'entry_id': 62161,
#   'field1': '1936.00',
#   'field2': None,
#   'field3': None},
#  {'created_at': '2020-08-13T12:45:20Z',
#   'entry_id': 62162,
#   'field1': None,
#   'field2': '66.00',
#   'field3': None},
#  {'created_at': '2020-08-13T12:45:36Z',
#   'entry_id': 62163,
#   'field1': None,
#   'field2': None,
#   'field3': '0.00'},
#  {'created_at': '2020-08-13T12:45:53Z',
#   'entry_id': 62164,
#   'field1': '1899.00',
#   'field2': None,
#   'field3': None},
#  {'created_at': '2020-08-13T12:46:09Z',
#   'entry_id': 62165,
#   'field1': None,
#   'field2': '65.00',
#   'field3': None},
#  {'created_at': '2020-08-13T12:46:25Z',
#   'entry_id': 62166,
#   'field1': None,
#   'field2': None,
#   'field3': '0.00'},
#  {'created_at': '2020-08-13T12:46:42Z',
#   'entry_id': 62167,
#   'field1': '1909.00',
#   'field2': None,
#   'field3': None},
#  {'created_at': '2020-08-13T12:46:58Z',
#   'entry_id': 62168,
#   'field1': None,
#   'field2': '65.00',
#   'field3': None},
#  {'created_at': '2020-08-13T12:47:14Z',
#   'entry_id': 62169,
#   'field1': None,
#   'field2': None,
#   'field3': '0.00'},
#  {'created_at': '2020-08-13T12:47:31Z',
#   'entry_id': 62170,
#   'field1': '1920.00',
#   'field2': None,
#   'field3': None},
#  {'created_at': '2020-08-13T12:47:47Z',
#   'entry_id': 62171,
#   'field1': None,
#   'field2': '66.00',
#   'field3': None},
#  {'created_at': '2020-08-13T12:48:03Z',
#   'entry_id': 62172,
#   'field1': None,
#   'field2': None,
#   'field3': '0.00'},
#  {'created_at': '2020-08-13T12:48:20Z',
#   'entry_id': 62173,
#   'field1': '1936.00',
#   'field2': None,
#   'field3': None},
#  {'created_at': '2020-08-13T12:48:36Z',
#   'entry_id': 62174,
#   'field1': None,
#   'field2': '68.00',
#   'field3': None},
#  {'created_at': '2020-08-13T12:48:53Z',
#   'entry_id': 62175,
#   'field1': None,
#   'field2': None,
#   'field3': '0.00'},
#  {'created_at': '2020-08-13T12:49:09Z',
#   'entry_id': 62176,
#   'field1': '1958.00',
#   'field2': None,
#   'field3': None},
#  {'created_at': '2020-08-13T12:49:25Z',
#   'entry_id': 62177,
#   'field1': None,
#   'field2': '66.00',
#   'field3': None},
#  {'created_at': '2020-08-13T12:49:42Z',
#   'entry_id': 62178,
#   'field1': None,
#   'field2': None,
#   'field3': '0.00'},
#  {'created_at': '2020-08-13T12:49:58Z',
#   'entry_id': 62179,
#   'field1': '1979.00',
#   'field2': None,
#   'field3': None},
#  {'created_at': '2020-08-13T12:50:15Z',
#   'entry_id': 62180,
#   'field1': None,
#   'field2': '67.00',
#   'field3': None},
#  {'created_at': '2020-08-13T12:50:31Z',
#   'entry_id': 62181,
#   'field1': None,
#   'field2': None,
#   'field3': '0.00'},
#  {'created_at': '2020-08-13T12:50:47Z',
#   'entry_id': 62182,
#   'field1': '1962.00',
#   'field2': None,
#   'field3': None},
#  {'created_at': '2020-08-13T12:51:04Z',
#   'entry_id': 62183,
#   'field1': None,
#   'field2': '65.00',
#   'field3': None},
#  {'created_at': '2020-08-13T12:51:20Z',
#   'entry_id': 62184,
#   'field1': None,
#   'field2': None,
#   'field3': '0.00'},
#  {'created_at': '2020-08-13T12:51:37Z',
#   'entry_id': 62185,
#   'field1': '1945.00',
#   'field2': None,
#   'field3': None},
#  {'created_at': '2020-08-13T12:51:53Z',
#   'entry_id': 62186,
#   'field1': None,
#   'field2': '66.00',
#   'field3': None},
#  {'created_at': '2020-08-13T12:52:09Z',
#   'entry_id': 62187,
#   'field1': None,
#   'field2': None,
#   'field3': '0.00'},
#  {'created_at': '2020-08-13T12:52:26Z',
#   'entry_id': 62188,
#   'field1': '1939.00',
#   'field2': None,
#   'field3': None},
#  {'created_at': '2020-08-13T12:52:42Z',
#   'entry_id': 62189,
#   'field1': None,
#   'field2': '66.00',
#   'field3': None},
#  {'created_at': '2020-08-13T12:52:58Z',
#   'entry_id': 62190,
#   'field1': None,
#   'field2': None,
#   'field3': '0.00'},
#  {'created_at': '2020-08-13T12:53:15Z',
#   'entry_id': 62191,
#   'field1': '1906.00',
#   'field2': None,
#   'field3': None},
#  {'created_at': '2020-08-13T12:53:31Z',
#   'entry_id': 62192,
#   'field1': None,
#   'field2': '66.00',
#   'field3': None},
#  {'created_at': '2020-08-13T12:53:48Z',
#   'entry_id': 62193,
#   'field1': None,
#   'field2': None,
#   'field3': '0.00'},
#  {'created_at': '2020-08-13T12:54:04Z',
#   'entry_id': 62194,
#   'field1': '1877.00',
#   'field2': None,
#   'field3': None},
#  {'created_at': '2020-08-13T12:54:20Z',
#   'entry_id': 62195,
#   'field1': None,
#   'field2': '68.00',
#   'field3': None},
#  {'created_at': '2020-08-13T12:54:37Z',
#   'entry_id': 62196,
#   'field1': None,
#   'field2': None,
#   'field3': '0.00'},
#  {'created_at': '2020-08-13T12:54:53Z',
#   'entry_id': 62197,
#   'field1': '1838.00',
#   'field2': None,
#   'field3': None},
#  {'created_at': '2020-08-13T12:55:10Z',
#   'entry_id': 62198,
#   'field1': None,
#   'field2': '66.00',
#   'field3': None},
#  {'created_at': '2020-08-13T12:55:26Z',
#   'entry_id': 62199,
#   'field1': None,
#   'field2': None,
#   'field3': '0.00'},
#  {'created_at': '2020-08-13T12:55:42Z',
#   'entry_id': 62200,
#   'field1': '1782.00',
#   'field2': None,
#   'field3': None},
#  {'created_at': '2020-08-13T12:55:59Z',
#   'entry_id': 62201,
#   'field1': None,
#   'field2': '65.00',
#   'field3': None},
#  {'created_at': '2020-08-13T12:56:15Z',
#   'entry_id': 62202,
#   'field1': None,
#   'field2': None,
#   'field3': '0.00'},
#  {'created_at': '2020-08-13T12:56:32Z',
#   'entry_id': 62203,
#   'field1': '1744.00',
#   'field2': None,
#   'field3': None},
#  {'created_at': '2020-08-13T12:56:48Z',
#   'entry_id': 62204,
#   'field1': None,
#   'field2': '66.00',
#   'field3': None},
#  {'created_at': '2020-08-13T12:57:04Z',
#   'entry_id': 62205,
#   'field1': None,
#   'field2': None,
#   'field3': '0.00'},
#  {'created_at': '2020-08-13T12:57:21Z',
#   'entry_id': 62206,
#   'field1': '1744.00',
#   'field2': None,
#   'field3': None},
#  {'created_at': '2020-08-13T12:57:37Z',
#   'entry_id': 62207,
#   'field1': None,
#   'field2': '66.00',
#   'field3': None},
#  {'created_at': '2020-08-13T12:57:53Z',
#   'entry_id': 62208,
#   'field1': None,
#   'field2': None,
#   'field3': '0.00'}]

# %%
data_from_room = pd.DataFrame().from_dict(dict_data_from_room['feeds'])
data_from_garage = pd.DataFrame().from_dict(dict_data_from_garage['feeds'])
data_from_room.to_excel('./data/room/pomiary.xlsx')
data_from_garage.to_excel('./data/garage/pomiary.xlsx')

# %%
(time.time() - start)
# Out:
# 0.8315532207489014

# %%
60*8
# Out:
# 480

# %%
type(time.asctime(time.gmtime()))
# Out:
# str
